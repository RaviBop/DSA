# %%
import numpy as np
import pandas as pd
import random
import scipy.stats
import matplotlib.pyplot as plt

# %%
government_office_region_name = ['East Midlands', 'East of England', 'London', 'MISSING', 'North East'
                                 'North West', 'Northern Ireland', 'Scotland' ,'South East', 'South West', 
                                 'Wales', 'West Midlands', 'Yorkshire and The Humber']

government_office_region_percentage = [6.65, 8.62, 16.1, 5.59, 3.95, 10.98, 0.48, 6.68, 11.78, 7.57, 4.29,
                                       9.27, 8.05]

age_percentage = [0.01,0.05,0.14,0.63,0.98,1.22,1.48,1.85,2.12,2.33,2.66,2.92,3.13,3.39,3.58,3.63,3.75,
                  3.59,3.5,3.46,3.35,3.22,3.08,3.06,2.95,2.66,2.43,2.22,2.12,2.01,1.99,1.87,1.8,1.78,1.66,
                  1.62,1.49,1.35,1.28,1.16,1.11,0.98,0.92,0.82,0.76,0.67,0.64,0.58,0.51,0.41,0.26,0.03,0.01,
                  0.01,0.01,0.01,4.76]

age_list = list(range(17,72))

ethnicity_name = ['Arab', 'Asian', 'Black', 'MISSING', 'Mixed', 'Other', 'Prefer not to say', 'White']

ethnicity_percentage = [0.46, 4.09, 2.64, 43.53, 1.39, 1.4, 2.26, 44.23]

ethnicity_subgroup_name = ['AFRICAN', 'ASIAN_OTHER', 'ASIAN_PREFER_NOT_TO_SAY', 'BANGLADESHI', 'BLACK_OTHER', 
                           'BLACK_PREFER_NOT_TO_SAY', 'BRITISH', 'CARIBBEAN', 'CHINESE', 'GYPSY', 'INDIAN',
                           'IRISH', 'MISSING', 'MIXED_OTHER', 'MIXED_PREFER_NOT_TO_SAY', 'PAKISTANI', 
                           'WHITE_AND_ASIAN', 'WHITE_AND_BLACK_AFRICAN', 'WHITE_AND_BLACK_CARIBBEAN',
                           'WHITE_OTHER', 'WHITE_PREFER_NOT_TO_SAY']

ethnicity_subgroup_percentage = [1.73,0.71,0.09,0.75,0.06,0.05,37.35,0.79,0.09,0.12,0.85,0.23,47.66,0.33,
                                 0.12,1.6,0.21,0.17,0.56,5.59,0.94]

sexual_orientation_name = ['BISEXUAL', 'GAY_OR_LESBIAN', 'HETEROSEXUAL', 'MISSING', 'OTHER' 'PREFER_NOT_TO_SAY']

sexual_orientation_percentage = [0.81, 0.74, 50.04, 43.53, 0.39, 4.48]

religion_name=['BUDDHIST', 'CHRISTIAN', 'HINDU', 'JEWISH', 'MISSING', 'MUSLIM', 'NONE', 'OTHER', 
               'PREFER_NOT_TO_SAY', 'SIKH']

religion_percentage = [0.29, 17.94, 0.42, 0.1, 43.53, 4.69, 27.57, 1.47, 3.68, 0.32]

marital_status_name = ['MARRIED_OR_IN_PARTNERSHIP', 'MISSING', 'NOT_MARRIED_OR_IN_PARTNERSHIP',
                       'PREFER_NOT_TO_SAY']

marital_status_percentage= [19.94, 43.53, 32.38, 4.15]

gender_name = ['F','M', 'MISSING']

gender_percentage= [0.46, 0.34, 99.21]

SE_name = ['0', '1']

SE_percentage = [60.32, 39.68]

children_name = ['MISSING', '0', '1', '2', '3', '4', '5', '6', '7']

children_percentage = [3.5, 37.6, 26.66, 24.18, 5.88, 1.67, 0.38, 0.09, 0.03]

couple_contract_name = ['f', 't']

couple_contract_percentage = [59.53, 40.47]

sample_name = ['RP0453_RQ9','RP0453_RQ9_1','RP0580','SA0017_RQ2','SA0017_RQ3','SA0017_RQ5','SA0018','SA0026',
              'SA0026_RQ2','SA0043','SA0116','SA0117']

sample_percentage = [0.04, 0.04, 0.17, 30.28, 8.91, 5.94, 2.97, 9.51, 9.27, 2.97, 29.63, 0.27]

# %%
synth_population_factor = 1000

# %%
#
# decided to keep age categorical for now.
#

first = True
for idx, age in enumerate(age_list):
    num_elements = round((age_percentage[idx] * synth_population_factor))
    if idx == 99:
        temp = np.full((1, num_elements), np.nan)
    else:
        temp = np.full((1, num_elements), age)
    if first == True:
        array = temp
        first = False
    else:
        array = np.append(array, temp)
        
array = array[0:synth_population_factor*100] #rouning errors remove unwanted elements.
age_df = pd.DataFrame(array)

# %%
first = True
for idx, region in enumerate(government_office_region_name):
    num_elements = round((government_office_region_percentage[idx] * synth_population_factor))
    temp = np.full((1, num_elements), region)
    if first == True:
        array = temp
        first = False
    else:
        array = np.append(array, temp)
        
array = array[0:synth_population_factor*100] #rouning errors remove unwanted elements.
region_df = pd.DataFrame(array)

#
# need to add more here for the other categorical data needed
#

# %%
first = True
for idx, ethnicity in enumerate(ethnicity_name):
    num_elements = round((ethnicity_percentage[idx] * synth_population_factor))
    temp = np.full((1, num_elements), ethnicity)
    if first == True:
        array = temp
        first = False
    else:
        array = np.append(array, temp)
        
array = array[0:synth_population_factor*100] #rouning errors remove unwanted elements.
ethnicity_df = pd.DataFrame(array)

# %%
first = True
for idx, ethnicity_subgroup in enumerate(ethnicity_subgroup_name):
    num_elements = round((ethnicity_subgroup_percentage[idx] * synth_population_factor))
    temp = np.full((1, num_elements), ethnicity_subgroup)
    if first == True:
        array = temp
        first = False
    else:
        array = np.append(array, temp)
        
array = array[0:synth_population_factor*100] #rouning errors remove unwanted elements.
ethnicity_subgroup_df = pd.DataFrame(array)

# %%
first = True
for idx, sexual_orientation in enumerate(sexual_orientation_name):
    num_elements = round((sexual_orientation_percentage[idx] * synth_population_factor))
    temp = np.full((1, num_elements), sexual_orientation)
    if first == True:
        array = temp
        first = False
    else:
        array = np.append(array, temp)
        
array = array[0:synth_population_factor*100] #rouning errors remove unwanted elements.
sexual_orientation_df = pd.DataFrame(array)

# %%
first = True
for idx, religion in enumerate(religion_name):
    num_elements = round((religion_percentage[idx] * synth_population_factor))
    temp = np.full((1, num_elements), religion)
    if first == True:
        array = temp
        first = False
    else:
        array = np.append(array, temp)
        
array = array[0:synth_population_factor*100] #rouning errors remove unwanted elements.
religion_df = pd.DataFrame(array)

# %%
first = True
for idx, marital_status in enumerate(marital_status_name):
    num_elements = round((marital_status_percentage[idx] * synth_population_factor))
    temp = np.full((1, num_elements), marital_status)
    if first == True:
        array = temp
        first = False
    else:
        array = np.append(array, temp)
        
array = array[0:synth_population_factor*100] #rouning errors remove unwanted elements.
marital_status_df = pd.DataFrame(array)

# %%
first = True
for idx, gender in enumerate(gender_name):
    num_elements = round((gender_percentage[idx] * synth_population_factor))
    temp = np.full((1, num_elements), gender)
    if first == True:
        array = temp
        first = False
    else:
        array = np.append(array, temp)
        
array = array[0:synth_population_factor*100] #rouning errors remove unwanted elements.
gender_df = pd.DataFrame(array)

# %%
first = True
for idx, SE in enumerate(SE_name):
    num_elements = round((SE_percentage[idx] * synth_population_factor))
    temp = np.full((1, num_elements), SE)
    if first == True:
        array = temp
        first = False
    else:
        array = np.append(array, temp)
        
array = array[0:synth_population_factor*100] #rouning errors remove unwanted elements.
SE_df = pd.DataFrame(array)

# %%
first = True
for idx, children in enumerate(children_name):
    num_elements = round((children_percentage[idx] * synth_population_factor))
    temp = np.full((1, num_elements), children)
    if first == True:
        array = temp
        first = False
    else:
        array = np.append(array, temp)
        
array = array[0:synth_population_factor*100] #rouning errors remove unwanted elements.
children_df = pd.DataFrame(array)

# %%
first = True
for idx, couple_contract in enumerate(couple_contract_name):
    num_elements = round((couple_contract_percentage[idx] * synth_population_factor))
    temp = np.full((1, num_elements), couple_contract)
    if first == True:
        array = temp
        first = False
    else:
        array = np.append(array, temp)
        
array = array[0:synth_population_factor*100] #rouning errors remove unwanted elements.
couple_contract_df = pd.DataFrame(array)

# %%
first = True
for idx, sample in enumerate(sample_name):
    num_elements = round((sample_percentage[idx] * synth_population_factor))
    temp = np.full((1, num_elements), sample)
    if first == True:
        array = temp
        first = False
    else:
        array = np.append(array, temp)
        
array = array[0:synth_population_factor*100] #rouning errors remove unwanted elements.
sample_df = pd.DataFrame(array)

# %%
def my_distribution(min_val, max_val, mean, std):
    scale = max_val - min_val
    location = min_val
    # Mean and standard deviation of the unscaled beta distribution
    unscaled_mean = (mean - min_val) / scale
    unscaled_var = (std / scale) ** 2
    # Computation of alpha and beta can be derived from mean and variance formulas
    t = unscaled_mean / (1 - unscaled_mean)
    beta = ((t / unscaled_var) - (t * t) - (2 * t) - 1) / ((t * t * t) + (3 * t * t) + (3 * t) + 1)
    alpha = beta * t
    # Not all parameters may produce a valid distribution
    if alpha <= 0 or beta <= 0:
        raise ValueError('Cannot create distribution for the given parameters.')
    # Make scaled beta distribution with computed parameters
    return scipy.stats.beta(alpha, beta, scale=scale, loc=location)

np.random.seed(100)

min_val = 0
max_val = 25373.9
mean = 652.9154
std = 1140.36
my_dist = my_distribution(min_val, max_val, mean, std)
# Plot distribution PDF
x = np.linspace(min_val, max_val, 100)
plt.plot(x, my_dist.pdf(x))
# Stats
print('mean:', my_dist.mean(), 'std:', my_dist.std())
# Get a large sample to check bounds
array = my_dist.rvs(size=1000000)
print('min:', array.min(), 'max:', array.max())

array = array[0:synth_population_factor*100] #rouning errors remove unwanted elements.
take_home_pay_df = pd.DataFrame(array)
# Out:
# mean: 652.9154 std: 1140.3599999999994
# min: 1.0226750014101346e-19 max: 16368.245955940483

# %%
np.random.seed(100)

min_val = 0
max_val = 4333.33
mean = 313.7807
std = 333.6543
my_dist = my_distribution(min_val, max_val, mean, std)
# Plot distribution PDF
x = np.linspace(min_val, max_val, 100)
plt.plot(x, my_dist.pdf(x))
# Stats
print('mean:', my_dist.mean(), 'std:', my_dist.std())
# Get a large sample to check bounds
array = my_dist.rvs(size=1000000)
print('min:', array.min(), 'max:', array.max())

array = array[0:synth_population_factor*100] #rouning errors remove unwanted elements.
housing_element_df = pd.DataFrame(array)
# Out:
# mean: 313.78069999999997 std: 333.65429999999986
# min: 1.1165245919875034e-06 max: 3160.913504316834

# %%
np.random.seed(100)

min_val = 0
max_val = 2362.11
mean = 269.9696
std = 266.3379
my_dist = my_distribution(min_val, max_val, mean, std)
# Plot distribution PDF
x = np.linspace(min_val, max_val, 100)
plt.plot(x, my_dist.pdf(x))
# Stats
print('mean:', my_dist.mean(), 'std:', my_dist.std())
# Get a large sample to check bounds
array = my_dist.rvs(size=1000000)
print('min:', array.min(), 'max:', array.max())

array = array[0:synth_population_factor*100] #rouning errors remove unwanted elements.
child_element_df = pd.DataFrame(array)
# Out:
# mean: 269.9696 std: 266.3379
# min: 3.876305678048078e-06 max: 2084.9663931406935

# %%
np.random.seed(100)

min_val = 0
max_val = 1729.41
mean = 8.409477
std = 53.72486
my_dist = my_distribution(min_val, max_val, mean, std)
# Plot distribution PDF
x = np.linspace(min_val, max_val, 100)
plt.plot(x, my_dist.pdf(x))
# Stats
print('mean:', my_dist.mean(), 'std:', my_dist.std())
# Get a large sample to check bounds
array = my_dist.rvs(size=1000000)
print('min:', array.min(), 'max:', array.max())

array = array[0:synth_population_factor*100] #rouning errors remove unwanted elements.
disabled_child_element_df = pd.DataFrame(array)
# Out:
# mean: 8.409477000000003 std: 53.72486000000001
# min: 0.0 max: 1513.489803676643

# %%
np.random.seed(100)

min_val = 0
max_val = 1108.45
mean = 11.09703
std = 69.59951
my_dist = my_distribution(min_val, max_val, mean, std)
# Plot distribution PDF
x = np.linspace(min_val, max_val, 100)
plt.plot(x, my_dist.pdf(x))
# Stats
print('mean:', my_dist.mean(), 'std:', my_dist.std())
# Get a large sample to check bounds
array = my_dist.rvs(size=1000000)
print('min:', array.min(), 'max:', array.max())

array = array[0:synth_population_factor*100] #rouning errors remove unwanted elements.
childcare_element_df = pd.DataFrame(array)
# Out:
# mean: 11.097029999999998 std: 69.59951
# min: 0.0 max: 1105.9554143299783

# %%
np.random.seed(100)

min_val = 0
max_val = 508.75
mean = 8.657092
std = 37.62441
my_dist = my_distribution(min_val, max_val, mean, std)
# Plot distribution PDF
x = np.linspace(min_val, max_val, 100)
plt.plot(x, my_dist.pdf(x))
# Stats
print('mean:', my_dist.mean(), 'std:', my_dist.std())
# Get a large sample to check bounds
array = my_dist.rvs(size=1000000)
print('min:', array.min(), 'max:', array.max())

array = array[0:synth_population_factor*100] #rouning errors remove unwanted elements.
carer_element_df = pd.DataFrame(array)
# Out:
# mean: 8.657092 std: 37.62440999999999
# min: 3.2083693520776034e-187 max: 506.8879517397087

# %%
index = list(range(0, 100000))
random.shuffle(index)

# %%
target_df = pd.DataFrame(index, columns=['pk'])

# %%
target_df = pd.concat([target_df, region_df, age_df, ethnicity_df, ethnicity_subgroup_df, 
                      sexual_orientation_df, religion_df, marital_status_df, gender_df,
                      SE_df, children_df, couple_contract_df, sample_df, take_home_pay_df, 
                      housing_element_df, child_element_df, disabled_child_element_df, 
                       childcare_element_df, carer_element_df], axis=1)

# %%
target_df = target_df.sort_values(by=['pk'], ignore_index=True)

# %%
target_df.columns=['ID','Government_Office_Region','Age','Ethnicity','Ethnicity_Subgroup','Sexual_Orientation',
                   'Religion','Marital_Status','Gender','SE_Flag','Children','Couple_Contract','Sample',
                   'Take_Home_Pay','Housing_Element','Child_Element','Disabled_Child_Element','Childcare_Element',
                   'Carer_Element']

# %%
target_df
# Out:
#           ID  Government_Office_Region   Age Ethnicity Ethnicity_Subgroup  \
# 0          0             East Midlands  23.0     Asian            BRITISH
# 1          1                South West  42.0     White            MISSING
# 2          2             West Midlands  51.0     White            MISSING
# 3          3                South West  42.0     White            MISSING
# 4          4             West Midlands  52.0     White            MISSING
# ...      ...                       ...   ...       ...                ...
# 99995  99995          Northern Ireland  37.0   MISSING            MISSING
# 99996  99996                South West  46.0     White            MISSING
# 99997  99997  Yorkshire and The Humber  61.0     White          PAKISTANI
# 99998  99998                     Wales  46.0     White            MISSING
# 99999  99999          Northern Ireland  38.0   MISSING            MISSING
#
#       Sexual_Orientation   Religion                 Marital_Status   Gender  \
# 0           HETEROSEXUAL  CHRISTIAN      MARRIED_OR_IN_PARTNERSHIP  MISSING
# 1                MISSING    MISSING                        MISSING  MISSING
# 2                MISSING       NONE  NOT_MARRIED_OR_IN_PARTNERSHIP  MISSING
# 3                MISSING     MUSLIM                        MISSING  MISSING
# 4                MISSING       NONE  NOT_MARRIED_OR_IN_PARTNERSHIP  MISSING
# ...                  ...        ...                            ...      ...
# 99995       HETEROSEXUAL    MISSING                        MISSING  MISSING
# 99996            MISSING       NONE  NOT_MARRIED_OR_IN_PARTNERSHIP  MISSING
# 99997            MISSING       NONE  NOT_MARRIED_OR_IN_PARTNERSHIP  MISSING
# 99998            MISSING       NONE  NOT_MARRIED_OR_IN_PARTNERSHIP  MISSING
# 99999       HETEROSEXUAL    MISSING                        MISSING  MISSING
#
#       SE_Flag Children Couple_Contract      Sample  Take_Home_Pay  \
# 0           0        0               f  SA0017_RQ2    1162.218501
# 1           1        1               t  SA0026_RQ2     225.942735
# 2           1        2               t      SA0116       0.017493
# 3           1        1               t  SA0026_RQ2     287.504788
# 4           1        2               t      SA0116      26.407892
# ...       ...      ...             ...         ...            ...
# 99995       0        1               f      SA0018     911.147810
# 99996       1        2               t      SA0116     144.535498
# 99997       1        2               t      SA0116    1854.882020
# 99998       1        2               t      SA0116      24.630812
# 99999       0        1               f      SA0018      23.105184
#
#        Housing_Element  Child_Element  Disabled_Child_Element  \
# 0           374.370907      81.222356            1.698286e-05
# 1           260.237869    1056.107006            5.366592e-24
# 2            19.171482     128.309024            1.793986e-14
# 3          1059.557344     202.767950            5.229414e-13
# 4           383.271160      76.208324            1.408726e+01
# ...                ...            ...                     ...
# 99995       218.606838       3.684274            6.909999e-16
# 99996       203.273751     483.513208            3.015463e-11
# 99997       346.146467      39.762819            1.412352e-13
# 99998        63.950314     482.149619            1.483684e-10
# 99999       190.124538      93.788964            8.438077e-25
#
#        Childcare_Element  Carer_Element
# 0           5.486639e-10   1.981729e+01
# 1           1.790270e+01   1.434817e-06
# 2           2.912521e-18   9.093027e-20
# 3           5.704369e-08   6.175460e-09
# 4           4.855443e-16   4.601132e-01
# ...                  ...            ...
# 99995       1.880521e-02   7.605469e-16
# 99996       1.260620e-02   1.893922e+01
# 99997       2.222424e+00   8.186724e-50
# 99998      1.757643e-106   8.945146e-01
# 99999       8.335002e-20   1.155984e+01
#
# [100000 rows x 19 columns]
